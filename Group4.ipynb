# %% [markdown]
# # Final Result

# %%
import pandas as pd

# %%
pd.read_csv(".//Model_Prediction//In-Sample-MSE.csv",index_col=0)
# Out:
#                                In-Sample-MSE
# DecisionTree                        1.112309
# GradientBoosting                   54.550886
# RandomForestQuantileRegressor      78.050718
# RandomForest                       74.329261
# Bagging                            66.878244

# %%
pd.read_csv(".//Model_Prediction//In-Sample-Efficiency.csv",index_col=0)
# Out:
#                                In-Sample-Efficiency
# DecisionTree                               0.952400
# GradientBoosting                           0.859148
# RandomForestQuantileRegressor              0.896589
# RandomForest                               0.873159
# Bagging                                    0.902692

# %%
pd.read_csv(".//Model_Prediction//Out-Sample-MSE.csv",index_col=0)
# Out:
#                                Out-Sample-MSE
# DecisionTree                      1183.410397
# GradientBoosting                   489.094265
# RandomForestQuantileRegressor      296.629900
# RandomForest                       318.541924
# Bagging                            314.264443

# %%
final_result = pd.read_csv(".//Model_Prediction//Bagging.csv")

# %%
final_result
# Out:
#       Unnamed: 0  productID  brandID  attribute1  attribute2  attribute3  \
# 0              0          0        4         3.0        90.0           2
# 1              1         88       36         4.0       100.0           1
# 2              2         82       11         3.0       100.0           2
# 3              3         38       14         3.0        80.0           3
# 4              4         21       26         2.0        50.0           5
# ...          ...        ...      ...         ...         ...         ...
# 1538        1538         43       12         3.0        60.0           1
# 1539        1539         36       19         3.0        60.0           5
# 1540        1540         24       26         2.0        50.0           2
# 1541        1541         36       19         3.0        60.0           2
# 1542        1542         90       35         4.0       100.0           1
#
#       attribute4  clickVolume  avgOriginalUnitPrice  avgFinalUnitPrice  ...  \
# ...

# %%
final_result.to_csv("group4.csv")
