# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %% [markdown]
# # 1. Import the train datasets

# %%
X_train = pd.read_csv("A_Normalised_train_data.csv",index_col=0)
Y_train = pd.read_csv("A_Log_sales_train.csv",index_col=0)

# %%
Model_1 = Ridge()

# %% [markdown]
# # 2. Setup Pipeline

# %%
poly = PolynomialFeatures()
pca=PCA()
SLR = Model_1

# %%
# Step 1: Polynomial transform
# Step 2: PCA
# Step 3: Model
pipe = Pipeline(steps=[("poly",poly),("pca",pca),("SLR",SLR)])

# %%
param_grid = {
    "pca__n_components": [45, 100 ,150 ,170],
    "poly__degree":[1,2],
    "SLR__alpha":[0.1,0.5,8,10,100]
}

# %% [markdown]
# # 3. Setup GridSearch

# %%
score_metric = 'neg_mean_squared_error'
search = GridSearchCV(pipe,param_grid,
                      n_jobs=-1,
                      cv=10,
                      scoring=score_metric)

# %%
search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('poly', PolynomialFeatures()),
#                                        ('pca', PCA()), ('SLR', Ridge())]),
#              n_jobs=-1,
#              param_grid={'SLR__alpha': [0.1, 0.5, 8, 10, 100],
#                          'pca__n_components': [45, 100, 150, 170],
#                          'poly__degree': [1, 2]},
#              scoring='neg_mean_squared_error')

# %%
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=-0.757):
# {'SLR__alpha': 100, 'pca__n_components': 150, 'poly__degree': 1}

# %%
df = pd.DataFrame(search.cv_results_)
df = df.sort_values(by=['rank_test_score'])
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 36       0.504199      0.089852         0.073105        0.061616
# 38       0.545669      0.050471         0.031949        0.040963
# 20       0.122850      0.010780         0.010844        0.005529
# 22       0.141231      0.025132         0.019013        0.010603
# 28       0.418946      0.183724         0.030166        0.024413
# 30       0.463849      0.155090         0.050961        0.059619
# 12       0.142645      0.039900         0.016986        0.010726
# 14       0.151643      0.025334         0.015442        0.006357
# 4        0.129033      0.016376         0.015158        0.005891
# 6        0.185005      0.024119         0.021542        0.012782
# 10       0.252339      0.041250         0.016937        0.002585
# 26       0.379633      0.076518         0.029223        0.028202
# 2        0.178072      0.027010         0.014326        0.008891
# 34       0.929609      0.056277         0.039694        0.049282
# 18       0.257301      0.053325         0.012699        0.005177
# 24       0.163803      0.018009         0.020913        0.013780
# 32       0.517116      0.080172         0.049567        0.046745
# 16       0.150186      0.011765         0.010870        0.005660
# 0        0.106824      0.015517         0.011393        0.006916
# 8        0.164504      0.034329         0.011733        0.006811
# 7       15.590709      0.297215         0.222951        0.034702
# 39      26.926028      4.692365         0.420774        0.164062
# 23      16.908977      1.525165         0.231582        0.070342
# 15      15.700865      0.474190         0.243418        0.050730
# 31      35.930453      5.296722         0.624077        0.328350
# 29      31.285141      4.314402         0.858818        0.113899
# 37      26.105445      6.786957         0.537549        0.297561
# 5       14.875868      1.079626         0.205841        0.026261
# 21      14.800976      1.003451         0.219396        0.030288
# 13      14.790391      0.609292         0.223571        0.041656
# 3       11.258197      0.601288         0.196773        0.046780
# 35      22.649914      5.790340         0.560627        0.194197
# 11      11.081205      0.483388         0.206547        0.036657
# 27      24.154283      1.597928         0.748551        0.182300
# 19      10.835731      0.594334         0.190074        0.032551
# 25      11.325878      2.681359         0.298562        0.130783
# 17       8.500843      0.350297         0.162160        0.040135
# 9        8.725169      0.355265         0.166421        0.025087
# 1        8.507356      0.557881         0.181157        0.042669
# 33      18.760642      3.531186         0.469644        0.206756
#
#    param_SLR__alpha param_pca__n_components param_poly__degree  \
# 36              100                     150                  1
# 38              100                     170                  1
# 20                8                     150                  1
# 22                8                     170                  1
# 28               10                     150                  1
# 30               10                     170                  1
# 12              0.5                     150                  1
# 14              0.5                     170                  1
# 4               0.1                     150                  1
# 6               0.1                     170                  1
# 10              0.5                     100                  1
# 26               10                     100                  1
# 2               0.1                     100                  1
# 34              100                     100                  1
# 18                8                     100                  1
# 24               10                      45                  1
# 32              100                      45                  1
# 16                8                      45                  1
# 0               0.1                      45                  1
# 8               0.5                      45                  1
# 7               0.1                     170                  2
# 39              100                     170                  2
# 23                8                     170                  2
# 15              0.5                     170                  2
# 31               10                     170                  2
# 29               10                     150                  2
# 37              100                     150                  2
# 5               0.1                     150                  2
# 21                8                     150                  2
# 13              0.5                     150                  2
# 3               0.1                     100                  2
# 35              100                     100                  2
# 11              0.5                     100                  2
# 27               10                     100                  2
# 19                8                     100                  2
# 25               10                      45                  2
# 17                8                      45                  2
# 9               0.5                      45                  2
# 1               0.1                      45                  2
# 33              100                      45                  2
#
#                                                params  split0_test_score  \
# 36  {'SLR__alpha': 100, 'pca__n_components': 150, ...          -0.557192
# 38  {'SLR__alpha': 100, 'pca__n_components': 170, ...          -0.557192
# 20  {'SLR__alpha': 8, 'pca__n_components': 150, 'p...          -0.513021
# 22  {'SLR__alpha': 8, 'pca__n_components': 170, 'p...          -0.513021
# 28  {'SLR__alpha': 10, 'pca__n_components': 150, '...          -0.514352
# 30  {'SLR__alpha': 10, 'pca__n_components': 170, '...          -0.514352
# 12  {'SLR__alpha': 0.5, 'pca__n_components': 150, ...          -0.507700
# 14  {'SLR__alpha': 0.5, 'pca__n_components': 170, ...          -0.507700
# 4   {'SLR__alpha': 0.1, 'pca__n_components': 150, ...          -0.507356
# 6   {'SLR__alpha': 0.1, 'pca__n_components': 170, ...          -0.507356
# 10  {'SLR__alpha': 0.5, 'pca__n_components': 100, ...          -0.724457
# 26  {'SLR__alpha': 10, 'pca__n_components': 100, '...          -0.739092
# 2   {'SLR__alpha': 0.1, 'pca__n_components': 100, ...          -0.739276
# 34  {'SLR__alpha': 100, 'pca__n_components': 100, ...          -0.720717
# 18  {'SLR__alpha': 8, 'pca__n_components': 100, 'p...          -0.742017
# 24  {'SLR__alpha': 10, 'pca__n_components': 45, 'p...          -0.774649
# 32  {'SLR__alpha': 100, 'pca__n_components': 45, '...          -0.800952
# 16  {'SLR__alpha': 8, 'pca__n_components': 45, 'po...          -0.795188
# 0   {'SLR__alpha': 0.1, 'pca__n_components': 45, '...          -0.786849
# 8   {'SLR__alpha': 0.5, 'pca__n_components': 45, '...          -0.821565
# 7   {'SLR__alpha': 0.1, 'pca__n_components': 170, ...          -0.684129
# 39  {'SLR__alpha': 100, 'pca__n_components': 170, ...          -0.659217
# 23  {'SLR__alpha': 8, 'pca__n_components': 170, 'p...          -0.649627
# 15  {'SLR__alpha': 0.5, 'pca__n_components': 170, ...          -0.663273
# 31  {'SLR__alpha': 10, 'pca__n_components': 170, '...          -0.677530
# 29  {'SLR__alpha': 10, 'pca__n_components': 150, '...          -0.715816
# 37  {'SLR__alpha': 100, 'pca__n_components': 150, ...          -0.706231
# 5   {'SLR__alpha': 0.1, 'pca__n_components': 150, ...          -0.716223
# 21  {'SLR__alpha': 8, 'pca__n_components': 150, 'p...          -0.716177
# 13  {'SLR__alpha': 0.5, 'pca__n_components': 150, ...          -0.705371
# 3   {'SLR__alpha': 0.1, 'pca__n_components': 100, ...          -0.901716
# 35  {'SLR__alpha': 100, 'pca__n_components': 100, ...          -0.901698
# 11  {'SLR__alpha': 0.5, 'pca__n_components': 100, ...          -0.901746
# 27  {'SLR__alpha': 10, 'pca__n_components': 100, '...          -0.901632
# 19  {'SLR__alpha': 8, 'pca__n_components': 100, 'p...          -0.901822
# 25  {'SLR__alpha': 10, 'pca__n_components': 45, 'p...          -1.251149
# 17  {'SLR__alpha': 8, 'pca__n_components': 45, 'po...          -1.251548
# 9   {'SLR__alpha': 0.5, 'pca__n_components': 45, '...          -1.273930
# 1   {'SLR__alpha': 0.1, 'pca__n_components': 45, '...          -1.253046
# 33  {'SLR__alpha': 100, 'pca__n_components': 45, '...          -1.251410
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 36          -0.551972  ...          -0.668318          -0.719911
# 38          -0.551972  ...          -0.668318          -0.719911
# 20          -0.547673  ...          -0.619544          -0.686219
# 22          -0.547673  ...          -0.619544          -0.686219
# 28          -0.546784  ...          -0.620699          -0.686463
# 30          -0.546784  ...          -0.620699          -0.686463
# 12          -0.553135  ...          -0.616896          -0.685685
# 14          -0.553135  ...          -0.616896          -0.685685
# 4           -0.553718  ...          -0.617224          -0.685505
# 6           -0.553718  ...          -0.617224          -0.685505
# 10          -0.711568  ...          -0.809943          -0.924437
# 26          -0.703795  ...          -0.810972          -0.922350
# 2           -0.715510  ...          -0.811637          -0.925968
# 34          -0.707963  ...          -0.819209          -0.945423
# 18          -0.705263  ...          -0.832567          -0.921932
# 24          -0.787414  ...          -0.882709          -0.985812
# 32          -0.833993  ...          -0.892170          -0.972988
# 16          -0.812030  ...          -0.866819          -0.987656
# 0           -0.806712  ...          -0.881945          -1.001522
# 8           -0.811911  ...          -0.907110          -0.985492
# 7           -0.648900  ...          -0.772479          -0.911908
# 39          -0.664496  ...          -0.747000          -0.906126
# 23          -0.652426  ...          -0.761841          -0.915414
# 15          -0.674197  ...          -0.749180          -0.915181
# 31          -0.656826  ...          -0.748238          -0.924773
# 29          -0.696454  ...          -0.847002          -0.944080
# 37          -0.692484  ...          -0.812567          -0.951846
# 5           -0.716635  ...          -0.820096          -0.944685
# 21          -0.724198  ...          -0.831174          -0.962281
# 13          -0.703348  ...          -0.823775          -0.938339
# 3           -0.874360  ...          -1.000153          -1.163167
# 35          -0.874186  ...          -1.000264          -1.163198
# 11          -0.874388  ...          -1.000295          -1.163251
# 27          -0.874381  ...          -1.000205          -1.163242
# 19          -0.874665  ...          -1.000207          -1.163243
# 25          -1.232447  ...          -1.434294          -1.402027
# 17          -1.227104  ...          -1.446028          -1.424866
# 9           -1.241792  ...          -1.444714          -1.427944
# 1           -1.230819  ...          -1.455881          -1.461065
# 33          -1.226277  ...          -1.451829          -1.446146
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 36          -0.566579          -0.569639          -0.613083
# 38          -0.566579          -0.569639          -0.613083
# 20          -0.546546          -0.564497          -0.565643
# 22          -0.546546          -0.564497          -0.565643
# 28          -0.546698          -0.563997          -0.566899
# 30          -0.546698          -0.563997          -0.566899
# 12          -0.547066          -0.565729          -0.561473
# 14          -0.547066          -0.565729          -0.561473
# 4           -0.547267          -0.565382          -0.561329
# 6           -0.547267          -0.565382          -0.561329
# 10          -0.722072          -0.667234          -0.776214
# 26          -0.722402          -0.669777          -0.764805
# 2           -0.712662          -0.675473          -0.781408
# 34          -0.714925          -0.671480          -0.765533
# 18          -0.716526          -0.659357          -0.778777
# 24          -0.701648          -0.763253          -0.869930
# 32          -0.740898          -0.747205          -0.815968
# 16          -0.724599          -0.701684          -0.837927
# 0           -0.746610          -0.729783          -0.847750
# 8           -0.714389          -0.755756          -0.846531
# 7           -0.706361          -0.643043          -0.677711
# 39          -0.699653          -0.641236          -0.667538
# 23          -0.701272          -0.655816          -0.681525
# 15          -0.711061          -0.662673          -0.686279
# 31          -0.707969          -0.646680          -0.682287
# 29          -0.746279          -0.668697          -0.699162
# 37          -0.737449          -0.667066          -0.700612
# 5           -0.745135          -0.662868          -0.696928
# 21          -0.739271          -0.670740          -0.700424
# 13          -0.741207          -0.672823          -0.706435
# 3           -0.872634          -0.835493          -0.903998
# 35          -0.872535          -0.835477          -0.904009
# 11          -0.872657          -0.835589          -0.903977
# 27          -0.872606          -0.835530          -0.904002
# 19          -0.872613          -0.835422          -0.904016
# 25          -1.017076          -1.244617          -1.227325
# 17          -1.023712          -1.233208          -1.217777
# 9           -1.009000          -1.222600          -1.226162
# 1           -1.004025          -1.209235          -1.219778
# 33          -1.024684          -1.230268          -1.225990
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 36          -0.671898          -0.616025        -0.756668        0.428507
# 38          -0.671898          -0.616025        -0.756668        0.428507
# 20          -0.640100          -0.603677        -0.756829        0.510501
# 22          -0.640100          -0.603677        -0.756829        0.510501
# 28          -0.640761          -0.602906        -0.756855        0.509700
# 30          -0.640761          -0.602906        -0.756855        0.509700
# 12          -0.638818          -0.609361        -0.756957        0.511264
# 14          -0.638818          -0.609361        -0.756957        0.511264
# 4           -0.641078          -0.610051        -0.757183        0.510955
# 6           -0.641078          -0.610051        -0.757183        0.510955
# 10          -0.830168          -0.791926        -0.784789        0.077534
# 26          -0.828913          -0.800581        -0.785002        0.076477
# 2           -0.831595          -0.803780        -0.787454        0.074641
# 34          -0.862158          -0.791273        -0.788175        0.084059
# 18          -0.816327          -0.810265        -0.789141        0.081488
# 24          -0.873834          -0.928220        -0.853455        0.089060
# 32          -0.847400          -0.947454        -0.854482        0.078533
# 16          -0.892826          -0.989184        -0.855629        0.095976
# 0           -0.868024          -0.960062        -0.864479        0.096296
# 8           -0.870729          -0.982520        -0.865419        0.088590
# 7           -0.840814          -0.792240        -0.866497        0.382790
# 39          -0.833879          -0.807946        -0.892428        0.475651
# 23          -0.846845          -0.789141        -0.898704        0.485709
# 15          -0.849566          -0.787380        -0.899696        0.473054
# 31          -0.845505          -0.806700        -0.901378        0.479692
# 29          -0.848629          -0.833380        -0.902012        0.382151
# 37          -0.848797          -0.853047        -0.902943        0.394991
# 5           -0.843720          -0.833124        -0.907671        0.404698
# 21          -0.852047          -0.838451        -0.909484        0.392747
# 13          -0.847321          -0.837695        -0.919794        0.441312
# 3           -1.001543          -1.026381        -0.959303        0.094281
# 35          -1.001555          -1.026379        -0.959355        0.094359
# 11          -1.001497          -1.026404        -0.959396        0.094321
# 27          -1.001518          -1.026407        -0.959398        0.094353
# 19          -1.001595          -1.026402        -0.959409        0.094311
# 25          -1.250099          -1.296170        -1.262227        0.106353
# 17          -1.268503          -1.307352        -1.267048        0.110995
# 9           -1.239174          -1.329789        -1.268011        0.115361
# 1           -1.240569          -1.329288        -1.268110        0.124193
# 33          -1.257899          -1.319994        -1.271051        0.115201
#
#     rank_test_score
# 36                1
# 38                1
# 20                3
# 22                3
# 28                5
# 30                5
# 12                7
# 14                8
# 4                 9
# 6                10
# 10               11
# 26               12
# 2                13
# 34               14
# 18               15
# 24               16
# 32               17
# 16               18
# 0                19
# 8                20
# 7                21
# 39               22
# 23               23
# 15               24
# 31               25
# 29               26
# 37               27
# 5                28
# 21               29
# 13               30
# 3                31
# 35               32
# 11               33
# 27               34
# 19               35
# 25               36
# 17               37
# 9                38
# 1                39
# 33               40
#
# [40 rows x 21 columns]

# %% [markdown]
# # 4. Best Hyperparameter

# %%
parms = pd.DataFrame(df['params'])
for i in parms.iloc[0]:
    print(i)
# Out:
# {'SLR__alpha': 100, 'pca__n_components': 150, 'poly__degree': 1}

# %% [markdown]
# # 5. Evaluate Model $log(Sales)$

# %%
best_pca =parms.iloc[0][0]['pca__n_components']
best_degree=parms.iloc[0][0]['poly__degree']
best_alpha=parms.iloc[0][0]['SLR__alpha']

# %%
Model_2 = Ridge(alpha=best_alpha)

# %%
poly1 = PolynomialFeatures(degree=best_degree)

# %%
X_train1,X_test1,Y_train1,Y_test1 = train_test_split(X_train,Y_train,test_size=0.2,random_state=132)

# %%
pca1 = PCA(n_components=best_pca)
X_train1 = poly1.fit_transform(X_train1)
pca1.fit(X_train1)
PX_train1 = pca1.transform(X_train1)
SLR1 = Model_2
SLR1.fit(PX_train1,Y_train1)
# Out:
# Ridge(alpha=100)

# %%
pca2 = PCA(n_components=best_pca)
X_test1=poly1.fit_transform(X_test1)
pca2.fit(X_test1)
PX_test1 = pca2.transform(X_test1)

# %%
MSE(SLR1.predict(PX_test1),Y_test1)
# Out:
# 2.061426182623276

# %%
result = pd.DataFrame(np.exp(Y_test1))

# %%
result["Predicted_sales"] = np.exp(SLR1.predict(PX_test1))

# %%
MSE(result["sales"],result["Predicted_sales"])
# Out:
# 1195.1841411090666

# %% [markdown]
# # 5.1 Model using original sales data

# %%
Model_3 = Ridge(alpha=best_alpha)

# %%
OY_train = pd.read_csv("A_sales_train.csv",index_col=0)

# %%
X_train2,X_test2,Y_train2,Y_test2 = train_test_split(X_train,OY_train,test_size=0.2,random_state=132)

# %%
pca3 = PCA(n_components=best_pca)
X_train2 = poly1.fit_transform(X_train2)
pca3.fit(X_train2)
PX_train2 = pca3.transform(X_train2)
SLR2 = Model_3
SLR2.fit(PX_train2,Y_train2)
# Out:
# Ridge(alpha=100)

# %%
pca4 = PCA(n_components=best_pca)
X_test2=poly1.fit_transform(X_test2)
pca4.fit(X_test2)
PX_test2 = pca4.transform(X_test2)

# %%
MSE(SLR2.predict(PX_test2),Y_test2)
# Out:
# 1807.7790377974325

# %% [markdown]
# #### Notably model trained on log(Sales) has lower out-of-sample MSE than model with unmodified Sales

# %% [markdown]
# # 6. Inventory Decision

# %%
residual = result['sales']-result['Predicted_sales']

# %%
Price=20
Cost=12
Salvage=8
Over=Cost - Salvage
Under=Price - Cost
Over, Under
# Out:
# (4, 8)

# %% [markdown]
# ### QQ plot to explore the distribution of residual

# %% [markdown]
# #### Normal Distribution

# %%
import scipy.stats as sct

# %%
import scipy
scipy.stats.probplot(residual, dist="norm", plot=plt)
plt.show()

# %%
s = residual.std()
opt_dec_N=np.ceil(sct.norm.ppf(Under/(Under+Over))*s + result['Predicted_sales'])

# %% [markdown]
# #### Exponential Distribution

# %%
scipy.stats.probplot(residual, dist="expon", plot=plt)
plt.show()

# %%
opt_dec_E=np.ceil((-result['Predicted_sales'])*np.log(1-(Under/(Under+Over))))

# %% [markdown]
# #### Empirical Distribution

# %%
size = residual.shape[0]
step=1/size
jumps = [step*i for i in range(1,size+1)]
Sample = sorted(residual)
plt.plot(Sample,jumps)

# %%
plt.hist(Sample)
plt.show()

# %%
def inv(sample,jump,area):
    size = len(sample)
    temp=0
    i=0
    while temp<area:
        temp=jump[i]
        i+=1
    return sample[i]

# %%
offset = inv(Sample,jumps,2/3)
offset
# Out:
# 6.949945810313061

# %%
opt_dec_B = np.ceil(result['Predicted_sales']+offset)

# %% [markdown]
# # 7. Out-of-samples Profit

# %%
#max profit for test data set
max_profit = result['sales'].sum()*(Price-Cost)
max_profit
# Out:
# 82096.0

# %%
def profit(demand,inv):
    return (Price-Salvage)*np.minimum(demand,inv)-(Cost-Salvage)*inv

# %%
#Profit (Normal)
profit_lst_N = profit(result['sales'],opt_dec_N)
profit_lst_N.sum()
# Out:
# 22076.0

# %%
#Profit (Exponential)
profit_lst_E = profit(result['sales'],opt_dec_E)
profit_lst_E.sum()
# Out:
# 22240.0

# %%
#Profit (Empirical)
profit_lst_B = profit(result['sales'],opt_dec_B)
profit_lst_B.sum()
# Out:
# 24872.0

# %% [markdown]
# # 8. K-Fold Cross Validation

# %% [markdown]
# ### Repeat steps 5,6,7 with 10-fold cross validation

# %%
Model_4=Ridge(alpha=best_alpha)

# %%
from sklearn.model_selection import KFold
k=10
kf = KFold(n_splits=k)
X_train_t=X_train.to_numpy()
Y_train_t=Y_train.to_numpy()
model = []
mse_lst = []
max_profit_lst = []
profit_N_lst = []
profit_E_lst = []
profit_B_lst = []

for train_index,test_index in kf.split(X_train_t):
    X_train_K,X_test_K=X_train_t[train_index],X_train_t[test_index]
    Y_train_K,Y_test_K=Y_train_t[train_index],Y_train_t[test_index]
    
    #PCA to transform train data
    pca_K1 = PCA(n_components=best_pca)
    X_train_K = poly1.fit_transform(X_train_K)
    pca_K1.fit(X_train_K)
    PX_train_K = pca_K1.transform(X_train_K)
    
    #Model
    SLR_K = Model_4
    SLR_K.fit(PX_train_K,Y_train_K)
    
    #pca to transform test data
    pca_K2 = PCA(n_components=best_pca)
    X_test_K=poly1.fit_transform(X_test_K)
    pca_K2.fit(X_test_K)
    PX_test_K = pca_K2.transform(X_test_K)
    
    #MSE
    mse_lst.append(MSE(SLR_K.predict(PX_test_K),Y_test_K))
    
    #Transform log(sale) back to sale
    result_K = pd.DataFrame(np.exp(Y_test_K))
    result_K["Predicted_sales"] = np.exp(SLR_K.predict(PX_test_K))
    
    #Obtain residual
    residual_K = result_K[0]-result_K['Predicted_sales']
    
    #Get std for Normal distribution
    s_K = residual.std()
    
    #Inventory Decision (Normal)
    opt_dec_N_K=np.ceil(sct.norm.ppf(Under/(Under+Over))*s_K + result_K['Predicted_sales'])
    #Inventory Decision (Exponential)
    opt_dec_E_K=np.ceil((-result_K['Predicted_sales'])*np.log(1-(Under/(Under+Over))))
    
    #Inventory Decision (Empirical Distribution)
    size_K = residual_K.shape[0]
    step_K=1/size_K
    jumps_K = [step_K*i for i in range(1,size+1)]
    Sample_K = sorted(residual_K)
    offset_K = inv(Sample_K,jumps_K,2/3)
    opt_dec_B_K = np.ceil(result_K['Predicted_sales']+offset_K)
    
    #Out-of_sample profit
    profit_lst_B_K = profit(result_K[0],opt_dec_B_K)
    profit_B_lst.append(profit_lst_B_K.sum())
    
    profit_lst_N_K = profit(result_K[0],opt_dec_N_K)
    profit_N_lst.append(profit_lst_N_K.sum())
    
    profit_lst_E_K = profit(result_K[0],opt_dec_E_K)
    profit_E_lst.append(profit_lst_E_K.sum())
    
    max_profit_K = result_K[0].sum()*(Price-Cost)
    max_profit_lst.append(max_profit_K)
    
max_profit_lst = np.array(max_profit_lst)
profit_N_lst = np.array(profit_N_lst)
profit_E_lst = np.array(profit_E_lst)
profit_B_lst = np.array(profit_B_lst)

fraction_of_max_N = profit_N_lst/max_profit_lst
fraction_of_max_E = profit_E_lst/max_profit_lst
fraction_of_max_B = profit_B_lst/max_profit_lst

dist_profit = ["Normal","Exponential","Empirical","Max"]
dist_frac = ["Normal","Exponential","Empirical"]
col_name = ["Dataset_"+str(i) for i in range(1,k+1)]

profit_lst = [profit_N_lst,profit_E_lst,profit_B_lst,max_profit_lst]
profit_table = pd.DataFrame(profit_lst,index=dist_profit,columns=col_name)
profit_table["mean_profit"]=profit_table.mean(axis=1)
profit_table["std_profit"]=profit_table.std(ddof=1,axis=1)

fraction_lst = [fraction_of_max_N,fraction_of_max_E,fraction_of_max_B]
fraction_table = pd.DataFrame(fraction_lst,index=dist_frac,columns=col_name)
fraction_table["mean_fraction"]=fraction_table.mean(axis=1)

# %%
fraction_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal        0.142181   0.235107  -0.075082   0.232017   0.106527   0.168203
# Exponential   0.116857   0.212834  -0.151460   0.209785   0.093392   0.131018
# Empirical     0.165958   0.260916  -0.067997   0.247725   0.130137   0.197603
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_fraction
# Normal        0.004003   0.225065   0.238815    0.044468       0.132130
# Exponential  -0.038474   0.182654   0.208572    0.026988       0.099217
# Empirical     0.022137   0.235212   0.253758    0.080292       0.152574

# %%
profit_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal          5884.0    10640.0    -3476.0    10812.0     5288.0     6568.0
# Exponential     4836.0     9632.0    -7012.0     9776.0     4636.0     5116.0
# Empirical       6868.0    11808.0    -3148.0    11544.0     6460.0     7716.0
# Max            41384.0    45256.0    46296.0    46600.0    49640.0    39048.0
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_profit  \
# Normal           196.0    10380.0    10676.0      1852.0       5882.0
# Exponential    -1884.0     8424.0     9324.0      1124.0       4397.2
# Empirical       1084.0    10848.0    11344.0      3344.0       6786.8
# Max            48968.0    46120.0    44704.0     41648.0      44966.4
#
#               std_profit
# Normal       4765.763318
# Exponential  5271.873458
# Empirical    4787.031163
# Max          3203.875254

# %%
profit_table.to_csv(".\\Model_Selection_Result\\2.5_Poly_reg_ridge.csv")
