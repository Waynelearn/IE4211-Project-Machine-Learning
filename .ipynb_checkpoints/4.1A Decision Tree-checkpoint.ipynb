# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # 1. Import the train datasets

# %%
X_train = pd.read_csv("A_Normalised_train_data.csv",index_col=0)
Y_train = pd.read_csv("A_Log_sales_train.csv",index_col=0)

# %%
Model_1 = KNeighborsRegressor()

# %% [markdown]
# # 2. Setup Pipeline

# %%
pca=PCA()
RG = Model_1

# %%
# Step 1: PCA
# Step 2: Model
pipe = Pipeline(steps=[("pca",pca),("RG",RG)])

# %%
param_grid = {
    "pca__n_components": [5, 10, 30, 45, 60, 100 ,150 ,170],
    "RG__n_neighbors":[1,4,5,6,7,8,10]
    
}

# %% [markdown]
# # 3. Setup GridSearch

# %%
score_metric = 'neg_mean_squared_error'
search = GridSearchCV(pipe,param_grid,
                      n_jobs=-1,
                      cv=10,
                      scoring=score_metric)

# %%
search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('pca', PCA()),
#                                        ('RG', KNeighborsRegressor())]),
#              n_jobs=-1,
#              param_grid={'RG__n_neighbors': [1, 4, 5, 6, 7, 8, 10],
#                          'pca__n_components': [5, 10, 30, 45, 60, 100, 150,
#                                                170]},
#              scoring='neg_mean_squared_error')

# %%
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=-0.804):
# {'RG__n_neighbors': 5, 'pca__n_components': 10}

# %%
df = pd.DataFrame(search.cv_results_)
df = df.sort_values(by=['rank_test_score'])
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17       0.054554      0.004927         0.011968        0.001093
# 33       0.061237      0.006941         0.013464        0.002453
# 25       0.058742      0.009725         0.014860        0.002765
# 41       0.060737      0.005649         0.014362        0.001424
# 9        0.069016      0.018663         0.017452        0.006970
# 24       0.043584      0.004550         0.011270        0.002641
# 40       0.048570      0.004571         0.011270        0.003570
# 16       0.046077      0.005121         0.009075        0.000698
# 32       0.046972      0.005265         0.011069        0.003816
# 49       0.055452      0.002410         0.014860        0.001809
# 48       0.047872      0.004063         0.011170        0.003084
# 8        0.064328      0.026885         0.015359        0.007919
# 42       0.075398      0.007055         0.032414        0.005853
# 18       0.070412      0.010005         0.033809        0.006683
# 26       0.077991      0.006672         0.031216        0.004462
# 10       0.084661      0.007132         0.028665        0.003812
# 34       0.075670      0.006689         0.032467        0.005706
# 50       0.078789      0.009802         0.031715        0.005140
# 43       0.112607      0.008024         0.072452        0.010365
# 27       0.104520      0.012016         0.067721        0.005650
# 51       0.108509      0.017565         0.074601        0.010169
# 11       0.107715      0.018172         0.065925        0.006483
# 35       0.106098      0.007885         0.074900        0.009539
# 28       0.116489      0.017411         0.127060        0.011777
# 44       0.114937      0.010166         0.119880        0.014431
# 19       0.114992      0.017412         0.076097        0.015713
# 52       0.116200      0.015952         0.126224        0.009896
# 36       0.111403      0.010917         0.118881        0.008940
# 20       0.121076      0.029023         0.140125        0.024069
# 55       0.120378      0.006165         0.364625        0.020240
# 54       0.121475      0.012447         0.334605        0.014942
# 39       0.116688      0.007608         0.398634        0.024483
# 38       0.120577      0.011796         0.329519        0.011054
# 47       0.121475      0.008306         0.408708        0.014979
# 46       0.114693      0.010916         0.327723        0.011426
# 53       0.169512      0.013257         0.212631        0.014581
# 12       0.106515      0.008940         0.109009        0.011319
# 30       0.122073      0.011356         0.317352        0.014039
# 31       0.125955      0.005948         0.397615        0.017607
# 45       0.178921      0.015694         0.215623        0.018400
# 37       0.169646      0.010301         0.212631        0.015654
# 22       0.135936      0.036078         0.330018        0.037815
# 23       0.124965      0.004907         0.401228        0.030844
# 29       0.172439      0.012259         0.211634        0.016392
# 15       0.121076      0.008628         0.393149        0.028462
# 14       0.130398      0.022405         0.337644        0.036320
# 21       0.172639      0.039532         0.261201        0.068744
# 13       0.171678      0.031964         0.237003        0.036784
# 1        0.066512      0.005914         0.013763        0.003332
# 2        0.080983      0.011077         0.028923        0.005659
# 0        0.063500      0.006498         0.012573        0.003554
# 3        0.121176      0.016377         0.074202        0.021247
# 4        0.122672      0.026206         0.101230        0.021737
# 7        0.132645      0.032042         0.377434        0.061098
# 6        0.128257      0.020117         0.272471        0.030671
# 5        0.178322      0.025536         0.170943        0.020921
#
#    param_RG__n_neighbors param_pca__n_components  \
# 17                     5                      10
# 33                     7                      10
# 25                     6                      10
# 41                     8                      10
# 9                      4                      10
# 24                     6                       5
# 40                     8                       5
# 16                     5                       5
# 32                     7                       5
# 49                    10                      10
# 48                    10                       5
# 8                      4                       5
# 42                     8                      30
# 18                     5                      30
# 26                     6                      30
# 10                     4                      30
# 34                     7                      30
# 50                    10                      30
# 43                     8                      45
# 27                     6                      45
# 51                    10                      45
# 11                     4                      45
# 35                     7                      45
# 28                     6                      60
# 44                     8                      60
# 19                     5                      45
# 52                    10                      60
# 36                     7                      60
# 20                     5                      60
# 55                    10                     170
# 54                    10                     150
# 39                     7                     170
# 38                     7                     150
# 47                     8                     170
# 46                     8                     150
# 53                    10                     100
# 12                     4                      60
# 30                     6                     150
# 31                     6                     170
# 45                     8                     100
# 37                     7                     100
# 22                     5                     150
# 23                     5                     170
# 29                     6                     100
# 15                     4                     170
# 14                     4                     150
# 21                     5                     100
# 13                     4                     100
# 1                      1                      10
# 2                      1                      30
# 0                      1                       5
# 3                      1                      45
# 4                      1                      60
# 7                      1                     170
# 6                      1                     150
# 5                      1                     100
#
#                                                params  split0_test_score  \
# 17    {'RG__n_neighbors': 5, 'pca__n_components': 10}          -0.790775
# 33    {'RG__n_neighbors': 7, 'pca__n_components': 10}          -0.745615
# 25    {'RG__n_neighbors': 6, 'pca__n_components': 10}          -0.744684
# 41    {'RG__n_neighbors': 8, 'pca__n_components': 10}          -0.776484
# 9     {'RG__n_neighbors': 4, 'pca__n_components': 10}          -0.773504
# 24     {'RG__n_neighbors': 6, 'pca__n_components': 5}          -0.795055
# 40     {'RG__n_neighbors': 8, 'pca__n_components': 5}          -0.804743
# 16     {'RG__n_neighbors': 5, 'pca__n_components': 5}          -0.846818
# 32     {'RG__n_neighbors': 7, 'pca__n_components': 5}          -0.817900
# 49   {'RG__n_neighbors': 10, 'pca__n_components': 10}          -0.782110
# 48    {'RG__n_neighbors': 10, 'pca__n_components': 5}          -0.816084
# 8      {'RG__n_neighbors': 4, 'pca__n_components': 5}          -0.815744
# 42    {'RG__n_neighbors': 8, 'pca__n_components': 30}          -0.798744
# 18    {'RG__n_neighbors': 5, 'pca__n_components': 30}          -0.773217
# 26    {'RG__n_neighbors': 6, 'pca__n_components': 30}          -0.810751
# 10    {'RG__n_neighbors': 4, 'pca__n_components': 30}          -0.744900
# 34    {'RG__n_neighbors': 7, 'pca__n_components': 30}          -0.789205
# 50   {'RG__n_neighbors': 10, 'pca__n_components': 30}          -0.788058
# 43    {'RG__n_neighbors': 8, 'pca__n_components': 45}          -0.836519
# 27    {'RG__n_neighbors': 6, 'pca__n_components': 45}          -0.780725
# 51   {'RG__n_neighbors': 10, 'pca__n_components': 45}          -0.830044
# 11    {'RG__n_neighbors': 4, 'pca__n_components': 45}          -0.763081
# 35    {'RG__n_neighbors': 7, 'pca__n_components': 45}          -0.803842
# 28    {'RG__n_neighbors': 6, 'pca__n_components': 60}          -0.846415
# 44    {'RG__n_neighbors': 8, 'pca__n_components': 60}          -0.826691
# 19    {'RG__n_neighbors': 5, 'pca__n_components': 45}          -0.776095
# 52   {'RG__n_neighbors': 10, 'pca__n_components': 60}          -0.879449
# 36    {'RG__n_neighbors': 7, 'pca__n_components': 60}          -0.868146
# 20    {'RG__n_neighbors': 5, 'pca__n_components': 60}          -0.850344
# 55  {'RG__n_neighbors': 10, 'pca__n_components': 170}          -0.876498
# 54  {'RG__n_neighbors': 10, 'pca__n_components': 150}          -0.876498
# 39   {'RG__n_neighbors': 7, 'pca__n_components': 170}          -0.868662
# 38   {'RG__n_neighbors': 7, 'pca__n_components': 150}          -0.868662
# 47   {'RG__n_neighbors': 8, 'pca__n_components': 170}          -0.895473
# 46   {'RG__n_neighbors': 8, 'pca__n_components': 150}          -0.895473
# 53  {'RG__n_neighbors': 10, 'pca__n_components': 100}          -0.884674
# 12    {'RG__n_neighbors': 4, 'pca__n_components': 60}          -0.837049
# 30   {'RG__n_neighbors': 6, 'pca__n_components': 150}          -0.886723
# 31   {'RG__n_neighbors': 6, 'pca__n_components': 170}          -0.886723
# 45   {'RG__n_neighbors': 8, 'pca__n_components': 100}          -0.912842
# 37   {'RG__n_neighbors': 7, 'pca__n_components': 100}          -0.895702
# 22   {'RG__n_neighbors': 5, 'pca__n_components': 150}          -0.867004
# 23   {'RG__n_neighbors': 5, 'pca__n_components': 170}          -0.867004
# 29   {'RG__n_neighbors': 6, 'pca__n_components': 100}          -0.884996
# 15   {'RG__n_neighbors': 4, 'pca__n_components': 170}          -0.917192
# 14   {'RG__n_neighbors': 4, 'pca__n_components': 150}          -0.917192
# 21   {'RG__n_neighbors': 5, 'pca__n_components': 100}          -0.881906
# 13   {'RG__n_neighbors': 4, 'pca__n_components': 100}          -0.937778
# 1     {'RG__n_neighbors': 1, 'pca__n_components': 10}          -0.937857
# 2     {'RG__n_neighbors': 1, 'pca__n_components': 30}          -0.897064
# 39        0.093795               32
# 38        0.093795               32
# 47        0.098452               34
# 46        0.098452               34
# 53        0.126947               36
# 12        0.112616               37
# 30        0.095722               38
# 31        0.095722               38
# 45        0.126604               40
# 37        0.125097               41
# 22        0.102895               42
# 23        0.102895               42
# 29        0.127937               44
# 15        0.093882               45
# 14        0.093882               45
# 21        0.120415               47
# 13        0.129463               48
# 1         0.106328               49
# 2         0.135229               50
# 0         0.125728               51
# 3         0.119794               52
# 4         0.160418               53
# 7         0.137158               54
# 6         0.137158               54
# 5         0.183120               56

# %% [markdown]
# # 4. Best Hyperparameter

# %%
parms = pd.DataFrame(df['params'])
for i in parms.iloc[0]:
    print(i)
# Out:
# {'RG__n_neighbors': 5, 'pca__n_components': 10}

# %% [markdown]
# # 5. Evaluate Model $log(Sales)$

# %%
best_pca =parms.iloc[0][0]['pca__n_components']
best_n = parms.iloc[0][0]['RG__n_neighbors']

# %%
Model_2 = KNeighborsRegressor(n_neighbors=best_n)

# %%
X_train1,X_test1,Y_train1,Y_test1 = train_test_split(X_train,Y_train,test_size=0.2,random_state=132)

# %%
pca1 = PCA(n_components=best_pca)
pca1.fit(X_train1)
PX_train1 = pca1.transform(X_train1)
RG1 = Model_2
RG1.fit(PX_train1,Y_train1)
# Out:
# KNeighborsRegressor()

# %%
pca2 = PCA(n_components=best_pca)
pca2.fit(X_test1)
PX_test1 = pca2.transform(X_test1)

# %%
MSE(RG1.predict(PX_test1),Y_test1)
# Out:
# 1.8432029638964762

# %%
result = pd.DataFrame(np.exp(Y_test1))

# %%
result["Predicted_sales"] = np.exp(RG1.predict(PX_test1))

# %%
MSE(result["sales"],result["Predicted_sales"])
# Out:
# 1096.9081871785475

# %% [markdown]
# # 5.1 Model using original sales data

# %%
Model_3 = KNeighborsRegressor(n_neighbors=best_n)

# %%
OY_train = pd.read_csv("A_sales_train.csv",index_col=0)

# %%
X_train2,X_test2,Y_train2,Y_test2 = train_test_split(X_train,OY_train,test_size=0.2,random_state=132)

# %%
pca3 = PCA(n_components=best_pca)
pca3.fit(X_train2)
PX_train2 = pca3.transform(X_train2)
RG2 = Model_3
RG2.fit(PX_train2,Y_train2)
# Out:
# KNeighborsRegressor()

# %%
pca4 = PCA(n_components=best_pca)
pca4.fit(X_test2)
PX_test2 = pca4.transform(X_test2)

# %%
MSE(RG2.predict(PX_test2),Y_test2)
# Out:
# 1203.7083369330453

# %% [markdown]
# #### Notably model trained on log(Sales) has lower out-of-sample MSE than model with unmodified Sales

# %% [markdown]
# # 6. Inventory Decision

# %%
residual = result['sales']-result['Predicted_sales']

# %%
Price=20
Cost=12
Salvage=8
Over=Cost - Salvage
Under=Price - Cost
Over, Under
# Out:
# (4, 8)

# %% [markdown]
# ### QQ plot to explore the distribution of residual

# %% [markdown]
# #### Normal Distribution

# %%
import scipy.stats as sct

# %%
import scipy
scipy.stats.probplot(residual, dist="norm", plot=plt)
plt.show()

# %%
s = residual.std()
opt_dec_N=np.ceil(sct.norm.ppf(Under/(Under+Over))*s + result['Predicted_sales'])

# %% [markdown]
# #### Exponential Distribution

# %%
scipy.stats.probplot(residual, dist="expon", plot=plt)
plt.show()

# %%
opt_dec_E=np.ceil((-result['Predicted_sales'])*np.log(1-(Under/(Under+Over))))

# %% [markdown]
# #### Empirical Distribution

# %%
size = residual.shape[0]
step=1/size
jumps = [step*i for i in range(1,size+1)]
Sample = sorted(residual)
plt.plot(Sample,jumps)

# %%
plt.hist(Sample)
plt.show()

# %%
def inv(sample,jump,area):
    size = len(sample)
    temp=0
    i=0
    while temp<area:
        temp=jump[i]
        i+=1
    return sample[i]

# %%
offset = inv(Sample,jumps,2/3)
offset
# Out:
# 9.422210511776456

# %%
opt_dec_B = np.ceil(result['Predicted_sales']+offset)

# %% [markdown]
# # 7. Out-of-samples Profit

# %%
#max profit for test data set
max_profit = result['sales'].sum()*(Price-Cost)
max_profit
# Out:
# 82096.0

# %%
def profit(demand,inv):
    return (Price-Salvage)*np.minimum(demand,inv)-(Cost-Salvage)*inv

# %%
#Profit (Normal)
profit_lst_N = profit(result['sales'],opt_dec_N)
profit_lst_N.sum()
# Out:
# 25924.0

# %%
#Profit (Exponential)
profit_lst_E = profit(result['sales'],opt_dec_E)
profit_lst_E.sum()
# Out:
# 22724.0

# %%
#Profit (Empirical)
profit_lst_B = profit(result['sales'],opt_dec_B)
profit_lst_B.sum()
# Out:
# 26980.0

# %% [markdown]
# # 8. K-Fold Cross Validation

# %% [markdown]
# ### Repeat steps 5,6,7 with 10-fold cross validation

# %%
Model_4=KNeighborsRegressor(n_neighbors=best_n)

# %%
from sklearn.model_selection import KFold
k=10
kf = KFold(n_splits=k)
X_train_t=X_train.to_numpy()
Y_train_t=Y_train.to_numpy()
model = []
mse_lst = []
max_profit_lst = []
profit_N_lst = []
profit_E_lst = []
profit_B_lst = []

for train_index,test_index in kf.split(X_train_t):
    X_train_K,X_test_K=X_train_t[train_index],X_train_t[test_index]
    Y_train_K,Y_test_K=Y_train_t[train_index],Y_train_t[test_index]
    
    #PCA to transform train data
    pca_K1 = PCA(n_components=best_pca)
    pca_K1.fit(X_train_K)
    PX_train_K = pca_K1.transform(X_train_K)
    
    #Model
    RG_K = Model_4
    RG_K.fit(PX_train_K,Y_train_K)
    
    #pca to transform test data
    pca_K2 = PCA(n_components=best_pca)
    pca_K2.fit(X_test_K)
    PX_test_K = pca_K2.transform(X_test_K)
    
    #MSE
    mse_lst.append(MSE(RG_K.predict(PX_test_K),Y_test_K))
    
    #Transform log(sale) back to sale
    result_K = pd.DataFrame(np.exp(Y_test_K))
    result_K["Predicted_sales"] = np.exp(RG_K.predict(PX_test_K))
    
    #Obtain residual
    residual_K = result_K[0]-result_K['Predicted_sales']
    
    #Get std for Normal distribution
    s_K = residual.std()
    
    #Inventory Decision (Normal)
    opt_dec_N_K=np.ceil(sct.norm.ppf(Under/(Under+Over))*s_K + result_K['Predicted_sales'])
    #Inventory Decision (Exponential)
    opt_dec_E_K=np.ceil((-result_K['Predicted_sales'])*np.log(1-(Under/(Under+Over))))
    
    #Inventory Decision (Empirical Distribution)
    size_K = residual_K.shape[0]
    step_K=1/size_K
    jumps_K = [step_K*i for i in range(1,size+1)]
    Sample_K = sorted(residual_K)
    offset_K = inv(Sample_K,jumps_K,2/3)
    opt_dec_B_K = np.ceil(result_K['Predicted_sales']+offset_K)
    
    #Out-of_sample profit
    profit_lst_B_K = profit(result_K[0],opt_dec_B_K)
    profit_B_lst.append(profit_lst_B_K.sum())
    
    profit_lst_N_K = profit(result_K[0],opt_dec_N_K)
    profit_N_lst.append(profit_lst_N_K.sum())
    
    profit_lst_E_K = profit(result_K[0],opt_dec_E_K)
    profit_E_lst.append(profit_lst_E_K.sum())
    
    max_profit_K = result_K[0].sum()*(Price-Cost)
    max_profit_lst.append(max_profit_K)
    
max_profit_lst = np.array(max_profit_lst)
profit_N_lst = np.array(profit_N_lst)
profit_E_lst = np.array(profit_E_lst)
profit_B_lst = np.array(profit_B_lst)

fraction_of_max_N = profit_N_lst/max_profit_lst
fraction_of_max_E = profit_E_lst/max_profit_lst
fraction_of_max_B = profit_B_lst/max_profit_lst

dist_profit = ["Normal","Exponential","Empirical","Max"]
dist_frac = ["Normal","Exponential","Empirical"]
col_name = ["Dataset_"+str(i) for i in range(1,k+1)]

profit_lst = [profit_N_lst,profit_E_lst,profit_B_lst,max_profit_lst]
profit_table = pd.DataFrame(profit_lst,index=dist_profit,columns=col_name)
profit_table["mean_profit"]=profit_table.mean(axis=1)
profit_table["std_profit"]=profit_table.std(ddof=1,axis=1)

fraction_lst = [fraction_of_max_N,fraction_of_max_E,fraction_of_max_B]
fraction_table = pd.DataFrame(fraction_lst,index=dist_frac,columns=col_name)
fraction_table["mean_fraction"]=fraction_table.mean(axis=1)

# %%
fraction_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal        0.278272   0.369012   0.231899   0.198026   0.236664   0.401455
# Exponential   0.249565   0.342319   0.179972   0.162747   0.203062   0.342963
# Empirical     0.292770   0.376525   0.236478   0.206867   0.243674   0.414669
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_fraction
# Normal        0.343571   0.317780   0.307981    0.269593       0.295425
# Exponential   0.289250   0.278925   0.251611    0.259700       0.256011
# Empirical     0.351495   0.322116   0.310666    0.293796       0.304906

# %%
profit_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal         11516.0    16700.0    10736.0     9228.0    11748.0    15676.0
# Exponential    10328.0    15492.0     8332.0     7584.0    10080.0    13392.0
# Empirical      12116.0    17040.0    10948.0     9640.0    12096.0    16192.0
# Max            41384.0    45256.0    46296.0    46600.0    49640.0    39048.0
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_profit  \
# Normal         16824.0    14656.0    13768.0     11228.0      13208.0
# Exponential    14164.0    12864.0    11248.0     10816.0      11430.0
# Empirical      17212.0    14856.0    13888.0     12236.0      13622.4
# Max            48968.0    46120.0    44704.0     41648.0      44966.4
#
#               std_profit
# Normal       2542.378729
# Exponential  2402.430936
# Empirical    2495.867432
# Max          3203.875254

# %%
profit_table.to_csv(".\\Model_Selection_Result\\3.1_KNN.csv")
