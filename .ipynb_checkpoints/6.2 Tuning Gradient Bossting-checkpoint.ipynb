# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
X_train = pd.read_csv("A_Normalised_train_data.csv",index_col=0)
Y_train = pd.read_csv("A_Log_sales_train.csv",index_col=0)

# %%
best_pca = 170
best_ccp_alpha = 0.005
best_n_est = 170

# %%
Model = RandomForestRegressor(ccp_alpha=best_ccp_alpha,n_estimators=best_n_est)

# %%
pca1 = PCA(n_components=best_pca)
pca1.fit(X_train)
PX_train = pca1.transform(X_train)
RG1 = Model
RG1.fit(PX_train,Y_train.values.ravel())
# Out:
# RandomForestRegressor(ccp_alpha=0.005, n_estimators=170)

# %%
MSE(RG1.predict(PX_train),Y_train)
# Out:
# 0.3596424906196233

# %%
result = pd.DataFrame(np.exp(Y_train))

# %%
result["Predicted_sales"] = np.exp(RG1.predict(PX_train))

# %%
MSE(result["sales"],result["Predicted_sales"])
# Out:
# 858.4563413152055

# %%
residual = result['sales']-result['Predicted_sales']

# %%
Price=20
Cost=12
Salvage=8
Over=Cost - Salvage
Under=Price - Cost
Over, Under
# Out:
# (4, 8)

# %%
import scipy.stats as sct

# %%
import scipy
scipy.stats.probplot(residual, dist="norm", plot=plt)
plt.show()

# %%
s = residual.std()
opt_dec_N=np.ceil(sct.norm.ppf(Under/(Under+Over))*s + result['Predicted_sales'])

# %%
scipy.stats.probplot(residual, dist="expon", plot=plt)
plt.show()

# %%
opt_dec_E=np.ceil((-result['Predicted_sales'])*np.log(1-(Under/(Under+Over))))

# %%
size = residual.shape[0]
step=1/size
jumps = [step*i for i in range(1,size+1)]
Sample = sorted(residual)
plt.plot(Sample,jumps)

# %%
plt.hist(Sample)
plt.show()

# %%
def inv(sample,jump,area):
    size = len(sample)
    temp=0
    i=0
    while temp<area:
        temp=jump[i]
        i+=1
    return sample[i]

# %%
offset = inv(Sample,jumps,2/3)
offset
# Out:
# 4.108222491638957

# %%
opt_dec_B = np.ceil(result['Predicted_sales']+offset)

# %%
#max profit for test data set
max_profit = result['sales'].sum()*(Price-Cost)
max_profit
# Out:
# 449664.0

# %%
def profit(demand,inv):
    return (Price-Salvage)*np.minimum(demand,inv)-(Cost-Salvage)*inv

# %%
#Profit (Normal)
profit_lst_N = profit(result['sales'],opt_dec_N)
profit_lst_N.sum()
# Out:
# 250564.0

# %%
#Profit (Exponential)
profit_lst_E = profit(result['sales'],opt_dec_E)
profit_lst_E.sum()
# Out:
# 278280.0

# %%
#Profit (Empirical)
profit_lst_B = profit(result['sales'],opt_dec_B)
profit_lst_B.sum()
# Out:
# 272072.0

# %%
result.to_csv(".\\Model_Prediction\\1_Random_forest.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-27-23186e7202f5> in <module>
# ----> 1 result.to_csv(".\\Model_Prediction\\1_Random_forest.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '.\\Model_Prediction\\1_Random_forest.csv'
