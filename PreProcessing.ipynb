# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("data-train.csv",index_col=1)
test = pd.read_csv("data-test.csv",index_col=1)

# %%
train.head()
# Out:
#            Unnamed: 0  brandID  attribute1  attribute2  attribute3  \
# productID
# 28                  0        4           3         100           5
# 73                  1       30           2          40           3
# 70                  2        3           3         100           1
# 69                  3       35           3         100           2
# 69                  4       35           3         100           7
#
#            attribute4  clickVolume  avgOriginalUnitPrice  avgFinalUnitPrice  \
# productID
# 28           2.098131          749             58.870968          53.774194
# 73           1.487173         1217            329.000000         146.111111
# 70           2.726300         3676            105.000000          64.797872
# 69           2.831175         2685            246.482759         204.448276
# 69           6.322161          777            250.000000         240.500000
#
#            ma14SalesVolume  weekday    meanAge    gender  meanEducation  \
# ...
