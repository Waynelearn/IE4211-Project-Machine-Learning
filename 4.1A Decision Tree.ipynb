# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
np.random.seed(42)

# %% [markdown]
# # 1. Import the train datasets

# %%
X_train = pd.read_csv("A_Normalised_train_data.csv",index_col=0)
Y_train = pd.read_csv("A_Log_sales_train.csv",index_col=0)

# %%
Model_1 = DecisionTreeRegressor()

# %% [markdown]
# # 2. Setup Pipeline

# %%
pca=PCA()
RG = Model_1

# %%
# Step 1: PCA
# Step 2: Model
pipe = Pipeline(steps=[("pca",pca),("RG",RG)])

# %%
param_grid = {
    "pca__n_components": [5, 10, 30, 45, 60, 100 ,150 ,170],
    "RG__ccp_alpha":[0,0.001,0.005,0.1,0.5,2,8]
    
}

# %% [markdown]
# # 3. Setup GridSearch

# %%
score_metric = 'neg_mean_squared_error'
search = GridSearchCV(pipe,param_grid,
                      n_jobs=-1,
                      cv=10,
                      scoring=score_metric)

# %%
search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('pca', PCA()),
#                                        ('RG', DecisionTreeRegressor())]),
#              n_jobs=-1,
#              param_grid={'RG__ccp_alpha': [0, 0.001, 0.005, 0.1, 0.5, 2, 8],
#                          'pca__n_components': [5, 10, 30, 45, 60, 100, 150,
#                                                170]},
#              scoring='neg_mean_squared_error')

# %%
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=-0.984):
# {'RG__ccp_alpha': 0.005, 'pca__n_components': 150}

# %%
df = pd.DataFrame(search.cv_results_)
df = df.sort_values(by=['rank_test_score'])
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 22       0.508383      0.061208         0.009794        0.004339
# 23       0.531722      0.069242         0.009426        0.004725
# 17       0.097732      0.018738         0.009973        0.007450
# 20       0.297570      0.041659         0.010804        0.003516
# 16       0.079171      0.016032         0.009246        0.004923
# 18       0.160753      0.009671         0.009046        0.005960
# 19       0.221703      0.012468         0.004687        0.007159
# 21       0.449543      0.045484         0.008967        0.004343
# 9        0.093711      0.012934         0.005285        0.006990
# 14       0.451791      0.032630         0.010171        0.006924
# 15       0.522961      0.068580         0.008244        0.003353
# 10       0.159337      0.011690         0.007811        0.007811
# 11       0.230768      0.035923         0.007811        0.007811
# 8        0.068734      0.010362         0.006248        0.007653
# 27       0.274450      0.057633         0.008180        0.006243
# 26       0.189936      0.030003         0.009929        0.003515
# 25       0.108711      0.028284         0.009141        0.005937
# 31       0.492553      0.069117         0.009790        0.006837
# 30       0.560125      0.092423         0.008337        0.003881
# 29       0.472607      0.069530         0.008444        0.002741
# 28       0.323632      0.053044         0.007529        0.002865
# 24       0.088525      0.020579         0.009375        0.004165
# 7        0.442626      0.027592         0.009607        0.007873
# 1        0.104260      0.044094         0.007647        0.004623
# 12       0.268109      0.017431         0.011261        0.008453
# 13       0.426083      0.031641         0.004687        0.007159
# 6        0.451983      0.034289         0.006249        0.007653
# 46       0.521805      0.054379         0.009176        0.002814
# 45       0.492694      0.040471         0.010373        0.006167
# 44       0.311244      0.038348         0.009179        0.002085
# 43       0.265582      0.035168         0.007281        0.004763
# 47       0.527290      0.066945         0.008079        0.001041
# 49       0.117985      0.020383         0.013662        0.015845
# 53       0.512729      0.081334         0.007679        0.001265
# 52       0.333707      0.058579         0.007680        0.001001
# 51       0.253921      0.056539         0.007979        0.001338
# 42       0.190420      0.014566         0.008970        0.003400
# 50       0.242950      0.106026         0.010472        0.003462
# 48       0.078291      0.009369         0.008577        0.003160
# 41       0.120605      0.021576         0.007293        0.003014
# 55       0.486479      0.058311         0.006283        0.002678
# 39       0.522969      0.060370         0.009121        0.004334
# 38       0.511318      0.067530         0.009796        0.005627
# 37       0.492186      0.093154         0.012148        0.008022
# 36       0.316231      0.033372         0.009176        0.003832
# 35       0.247695      0.021608         0.009154        0.002931
# 34       0.198407      0.033526         0.009650        0.004086
# 33       0.109842      0.018158         0.009774        0.003332
# 32       0.071973      0.011480         0.006948        0.007369
# 54       0.532875      0.077475         0.008677        0.003485
# 40       0.078687      0.016628         0.009290        0.003861
# 2        0.158582      0.018133         0.009442        0.005163
# 3        0.219841      0.015797         0.009373        0.007653
# 4        0.269554      0.033862         0.006248        0.007653
# 5        0.417953      0.027769         0.006249        0.007653
# 0        0.097133      0.027856         0.007147        0.005442
#
#    param_RG__ccp_alpha param_pca__n_components  \
# 22               0.005                     150
# 23               0.005                     170
# 17               0.005                      10
# 20               0.005                      60
# 16               0.005                       5
# 18               0.005                      30
# 19               0.005                      45
# 21               0.005                     100
# 9                0.001                      10
# 14               0.001                     150
# 15               0.001                     170
# 10               0.001                      30
# 11               0.001                      45
# 8                0.001                       5
# 27                 0.1                      45
# 26                 0.1                      30
# 25                 0.1                      10
# 31                 0.1                     170
# 30                 0.1                     150
# 29                 0.1                     100
# 28                 0.1                      60
# 24                 0.1                       5
# 7                    0                     170
# 1                    0                      10
# 12               0.001                      60
# 13               0.001                     100
# 6                    0                     150
# 46                   2                     150
# 45                   2                     100
# 44                   2                      60
# 43                   2                      45
# 47                   2                     170
# 49                   8                      10
# 53                   8                     100
# 52                   8                      60
# 51                   8                      45
# 42                   2                      30
# 50                   8                      30
# 48                   8                       5
# 41                   2                      10
# 55                   8                     170
# 39                 0.5                     170
# 38                 0.5                     150
# 37                 0.5                     100
# 36                 0.5                      60
# 35                 0.5                      45
# 34                 0.5                      30
# 33                 0.5                      10
# 32                 0.5                       5
# 54                   8                     150
# 40                   2                       5
# 2                    0                      30
# 3                    0                      45
# 4                    0                      60
# 5                    0                     100
# 0                    0                       5
#
#                                                params  split0_test_score  \
# 22  {'RG__ccp_alpha': 0.005, 'pca__n_components': ...          -0.977416
# 23  {'RG__ccp_alpha': 0.005, 'pca__n_components': ...          -0.977416
# 17  {'RG__ccp_alpha': 0.005, 'pca__n_components': 10}          -0.902207
# 20  {'RG__ccp_alpha': 0.005, 'pca__n_components': 60}          -0.974354
# 16   {'RG__ccp_alpha': 0.005, 'pca__n_components': 5}          -0.941162
# 18  {'RG__ccp_alpha': 0.005, 'pca__n_components': 30}          -1.040513
# 19  {'RG__ccp_alpha': 0.005, 'pca__n_components': 45}          -1.031890
# 21  {'RG__ccp_alpha': 0.005, 'pca__n_components': ...          -0.969634
# 9   {'RG__ccp_alpha': 0.001, 'pca__n_components': 10}          -1.327829
# 14  {'RG__ccp_alpha': 0.001, 'pca__n_components': ...          -1.301228
# 15  {'RG__ccp_alpha': 0.001, 'pca__n_components': ...          -1.317220
# 10  {'RG__ccp_alpha': 0.001, 'pca__n_components': 30}          -1.196255
# 11  {'RG__ccp_alpha': 0.001, 'pca__n_components': 45}          -1.068557
# 8    {'RG__ccp_alpha': 0.001, 'pca__n_components': 5}          -1.184105
# 27    {'RG__ccp_alpha': 0.1, 'pca__n_components': 45}          -1.175923
# 26    {'RG__ccp_alpha': 0.1, 'pca__n_components': 30}          -1.164312
# 25    {'RG__ccp_alpha': 0.1, 'pca__n_components': 10}          -1.154398
# 31   {'RG__ccp_alpha': 0.1, 'pca__n_components': 170}          -1.175765
# 30   {'RG__ccp_alpha': 0.1, 'pca__n_components': 150}          -1.175765
# 29   {'RG__ccp_alpha': 0.1, 'pca__n_components': 100}          -1.175808
# 28    {'RG__ccp_alpha': 0.1, 'pca__n_components': 60}          -1.175921
# 24     {'RG__ccp_alpha': 0.1, 'pca__n_components': 5}          -1.153604
# 7      {'RG__ccp_alpha': 0, 'pca__n_components': 170}          -1.423906
# 1       {'RG__ccp_alpha': 0, 'pca__n_components': 10}          -1.197652
# 12  {'RG__ccp_alpha': 0.001, 'pca__n_components': 60}          -1.463914
# 13  {'RG__ccp_alpha': 0.001, 'pca__n_components': ...          -1.321456
# 6      {'RG__ccp_alpha': 0, 'pca__n_components': 150}          -1.480991
# 46     {'RG__ccp_alpha': 2, 'pca__n_components': 150}          -1.335629
# 45     {'RG__ccp_alpha': 2, 'pca__n_components': 100}          -1.335629
# 44      {'RG__ccp_alpha': 2, 'pca__n_components': 60}          -1.335629
# 43      {'RG__ccp_alpha': 2, 'pca__n_components': 45}          -1.335629
# 47     {'RG__ccp_alpha': 2, 'pca__n_components': 170}          -1.335629
# 49      {'RG__ccp_alpha': 8, 'pca__n_components': 10}          -1.335629
# 53     {'RG__ccp_alpha': 8, 'pca__n_components': 100}          -1.335629
# 52      {'RG__ccp_alpha': 8, 'pca__n_components': 60}          -1.335629
# 51      {'RG__ccp_alpha': 8, 'pca__n_components': 45}          -1.335629
# 42      {'RG__ccp_alpha': 2, 'pca__n_components': 30}          -1.335629
# 50      {'RG__ccp_alpha': 8, 'pca__n_components': 30}          -1.335629
# 48       {'RG__ccp_alpha': 8, 'pca__n_components': 5}          -1.335629
# 41      {'RG__ccp_alpha': 2, 'pca__n_components': 10}          -1.335629
# 35          -1.347467          -1.382383          -1.351740        -1.392170
# 34          -1.347467          -1.382383          -1.351740        -1.392170
# 33          -1.347467          -1.382383          -1.351740        -1.392170
# 32          -1.347467          -1.382383          -1.351740        -1.392170
# 54          -1.347467          -1.382383          -1.351740        -1.392170
# 40          -1.347467          -1.382383          -1.351740        -1.392170
# 2           -1.317326          -1.500176          -1.728484        -1.403373
# 3           -1.475111          -1.224060          -1.442852        -1.418532
# 4           -1.476485          -1.262276          -1.535092        -1.421803
# 5           -1.150600          -1.721313          -1.474752        -1.490769
# 0           -1.421434          -1.273009          -1.452122        -1.523249
#
#     std_test_score  rank_test_score
# 22        0.115972                1
# 23        0.115296                2
# 17        0.083264                3
# 20        0.097380                4
# 16        0.137647                5
# 18        0.045697                6
# 19        0.089574                7
# 21        0.110397                8
# 9         0.151043                9
# 14        0.161807               10
# 15        0.164640               11
# 10        0.153637               12
# 11        0.112109               13
# 8         0.100840               14
# 27        0.134832               15
# 26        0.146179               16
# 25        0.156894               17
# 31        0.130908               18
# 30        0.130908               18
# 29        0.131936               20
# 28        0.135968               21
# 24        0.130543               22
# 7         0.202059               23
# 1         0.188844               24
# 12        0.171681               25
# 13        0.065950               26
# 6         0.179290               27
# 46        0.152115               28
# 45        0.152115               28
# 44        0.152115               28
# 43        0.152115               28
# 47        0.152115               28
# 49        0.152115               28
# 53        0.152115               28
# 52        0.152115               28
# 51        0.152115               28
# 42        0.152115               28
# 50        0.152115               28
# 48        0.152115               28
# 41        0.152115               28
# 55        0.152115               28
# 39        0.152115               28
# 38        0.152115               28
# 37        0.152115               28
# 36        0.152115               28
# 35        0.152115               28
# 34        0.152115               28
# 33        0.152115               28
# 32        0.152115               28
# 54        0.152115               28
# 40        0.152115               28
# 2         0.210809               52
# 3         0.130895               53
# 4         0.199809               54
# 5         0.184631               55
# 0         0.260516               56

# %% [markdown]
# # 4. Best Hyperparameter

# %%
parms = pd.DataFrame(df['params'])
for i in parms.iloc[0]:
    print(i)
# Out:
# {'RG__ccp_alpha': 0.005, 'pca__n_components': 150}

# %% [markdown]
# # 5. Evaluate Model $log(Sales)$

# %%
best_pca =parms.iloc[0][0]['pca__n_components']
best_ccp_alpha = parms.iloc[0][0]['RG__ccp_alpha']

# %%
Model_2 = DecisionTreeRegressor(ccp_alpha=best_ccp_alpha)

# %%
X_train1,X_test1,Y_train1,Y_test1 = train_test_split(X_train,Y_train,test_size=0.2,random_state=132)

# %%
pca1 = PCA(n_components=best_pca)
pca1.fit(X_train1)
PX_train1 = pca1.transform(X_train1)
RG1 = Model_2
RG1.fit(PX_train1,Y_train1)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.005)

# %%
pca2 = PCA(n_components=best_pca)
pca2.fit(X_test1)
PX_test1 = pca2.transform(X_test1)

# %%
MSE(RG1.predict(PX_test1),Y_test1)
# Out:
# 1.9334966831039164

# %%
result = pd.DataFrame(np.exp(Y_test1))

# %%
result["Predicted_sales"] = np.exp(RG1.predict(PX_test1))

# %%
MSE(result["sales"],result["Predicted_sales"])
# Out:
# 1224.773819695443

# %% [markdown]
# # 5.1 Model using original sales data

# %%
Model_3 = DecisionTreeRegressor(ccp_alpha=best_ccp_alpha)

# %%
OY_train = pd.read_csv("A_sales_train.csv",index_col=0)

# %%
X_train2,X_test2,Y_train2,Y_test2 = train_test_split(X_train,OY_train,test_size=0.2,random_state=132)

# %%
pca3 = PCA(n_components=best_pca)
pca3.fit(X_train2)
PX_train2 = pca3.transform(X_train2)
RG2 = Model_3
RG2.fit(PX_train2,Y_train2)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.005)

# %%
pca4 = PCA(n_components=best_pca)
pca4.fit(X_test2)
PX_test2 = pca4.transform(X_test2)

# %%
MSE(RG2.predict(PX_test2),Y_test2)
# Out:
# 2987.0157601202636

# %% [markdown]
# #### Notably model trained on log(Sales) has lower out-of-sample MSE than model with unmodified Sales

# %% [markdown]
# # 6. Inventory Decision

# %%
residual = result['sales']-result['Predicted_sales']

# %%
Price=20
Cost=12
Salvage=8
Over=Cost - Salvage
Under=Price - Cost
Over, Under
# Out:
# (4, 8)

# %% [markdown]
# ### QQ plot to explore the distribution of residual

# %% [markdown]
# #### Normal Distribution

# %%
import scipy.stats as sct

# %%
import scipy
scipy.stats.probplot(residual, dist="norm", plot=plt)
plt.show()

# %%
s = residual.std()
opt_dec_N=np.ceil(sct.norm.ppf(Under/(Under+Over))*s + result['Predicted_sales'])

# %% [markdown]
# #### Exponential Distribution

# %%
scipy.stats.probplot(residual, dist="expon", plot=plt)
plt.show()

# %%
opt_dec_E=np.ceil((-result['Predicted_sales'])*np.log(1-(Under/(Under+Over))))

# %% [markdown]
# #### Empirical Distribution

# %%
size = residual.shape[0]
step=1/size
jumps = [step*i for i in range(1,size+1)]
Sample = sorted(residual)
plt.plot(Sample,jumps)

# %%
plt.hist(Sample)
plt.show()

# %%
def inv(sample,jump,area):
    size = len(sample)
    i=0
    temp=jump[i]
    while temp<area:
        i+=1
        temp=jump[i]
        
    return sample[i]

# %%
offset = inv(Sample,jumps,2/3)
offset
# Out:
# 8.193746946785616

# %%
opt_dec_B = np.ceil(result['Predicted_sales']+offset)

# %% [markdown]
# # 7. Out-of-samples Profit

# %%
#max profit for test data set
max_profit = result['sales'].sum()*(Price-Cost)
max_profit
# Out:
# 82096.0

# %%
def profit(demand,inv):
    return (Price-Salvage)*np.minimum(demand,inv)-(Cost-Salvage)*inv

# %%
#Profit (None)
profit_lst = profit(round(result['sales']),round(result['Predicted_sales']))
profit_lst.sum()
# Out:
# 20856.0

# %%
#Profit (Normal)
profit_lst_N = profit(result['sales'],opt_dec_N)
profit_lst_N.sum()
# Out:
# 22020.0

# %%
#Profit (Exponential)
profit_lst_E = profit(result['sales'],opt_dec_E)
profit_lst_E.sum()
# Out:
# 20672.0

# %%
#Profit (Empirical)
profit_lst_B = profit(result['sales'],opt_dec_B)
profit_lst_B.sum()
# Out:
# 24412.0

# %% [markdown]
# # 8. K-Fold Cross Validation

# %% [markdown]
# ### Repeat steps 5,6,7 with 10-fold cross validation

# %%
Model_4=DecisionTreeRegressor(ccp_alpha=best_ccp_alpha)

# %%
from sklearn.model_selection import KFold
k=10
kf = KFold(n_splits=k)
X_train_t=X_train.to_numpy()
Y_train_t=Y_train.to_numpy()
model = []
mse_lst = []
max_profit_lst = []
profit_N_lst = []
profit_E_lst = []
profit_B_lst = []

for train_index,test_index in kf.split(X_train_t):
    X_train_K,X_test_K=X_train_t[train_index],X_train_t[test_index]
    Y_train_K,Y_test_K=Y_train_t[train_index],Y_train_t[test_index]
    
    #PCA to transform train data
    pca_K1 = PCA(n_components=best_pca,random_state=42)
    pca_K1.fit(X_train_K)
    PX_train_K = pca_K1.transform(X_train_K)
    
    #Model
    RG_K = Model_4
    RG_K.fit(PX_train_K,Y_train_K)
    
    #pca to transform test data
    pca_K2 = PCA(n_components=best_pca,random_state=42)
    pca_K2.fit(X_test_K)
    PX_test_K = pca_K2.transform(X_test_K)
    
    #MSE
    mse_lst.append(MSE(np.exp(RG_K.predict(PX_test_K)),np.exp(Y_test_K)))
    
    #Transform log(sale) back to sale
    result_K = pd.DataFrame(np.exp(Y_test_K))
    result_K["Predicted_sales"] = np.exp(RG_K.predict(PX_test_K))
    
    #Obtain residual
    residual_K = result_K[0]-result_K['Predicted_sales']
    
    #Get std for Normal distribution
    s_K = residual.std()
    
    #Inventory Decision (Normal)
    opt_dec_N_K=np.ceil(sct.norm.ppf(Under/(Under+Over))*s_K + result_K['Predicted_sales'])
    #Inventory Decision (Exponential)
    opt_dec_E_K=np.ceil((-result_K['Predicted_sales'])*np.log(1-(Under/(Under+Over))))
    
    #Inventory Decision (Empirical Distribution)
    size_K = residual_K.shape[0]
    step_K=1/size_K
    jumps_K = [step_K*i for i in range(1,size+1)]
    Sample_K = sorted(residual_K)
    offset_K = inv(Sample_K,jumps_K,2/3)
    opt_dec_B_K = np.ceil(result_K['Predicted_sales']+offset_K)
    
    #Out-of_sample profit
    profit_lst_B_K = profit(result_K[0],opt_dec_B_K)
    profit_B_lst.append(profit_lst_B_K.sum())
    
    profit_lst_N_K = profit(result_K[0],opt_dec_N_K)
    profit_N_lst.append(profit_lst_N_K.sum())
    
    profit_lst_E_K = profit(result_K[0],opt_dec_E_K)
    profit_E_lst.append(profit_lst_E_K.sum())
    
    max_profit_K = result_K[0].sum()*(Price-Cost)
    max_profit_lst.append(max_profit_K)
    
max_profit_lst = np.array(max_profit_lst)
profit_N_lst = np.array(profit_N_lst)
profit_E_lst = np.array(profit_E_lst)
profit_B_lst = np.array(profit_B_lst)

fraction_of_max_N = profit_N_lst/max_profit_lst
fraction_of_max_E = profit_E_lst/max_profit_lst
fraction_of_max_B = profit_B_lst/max_profit_lst

dist_profit = ["Normal","Exponential","Empirical","Max"]
dist_frac = ["Normal","Exponential","Empirical"]
col_name = ["Dataset_"+str(i) for i in range(1,k+1)]

profit_lst = [profit_N_lst,profit_E_lst,profit_B_lst,max_profit_lst]
profit_table = pd.DataFrame(profit_lst,index=dist_profit,columns=col_name)
profit_table["mean_profit"]=profit_table.mean(axis=1)
profit_table["std_profit"]=profit_table.std(ddof=1,axis=1)

fraction_lst = [fraction_of_max_N,fraction_of_max_E,fraction_of_max_B]
fraction_table = pd.DataFrame(fraction_lst,index=dist_frac,columns=col_name)
fraction_table["mean_fraction"]=fraction_table.mean(axis=1)

# %%
fraction_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal        0.218152   0.284250   0.317695   0.211159   0.221193   0.290514
# Exponential   0.261260   0.264274   0.258856   0.221373   0.251088   0.282934
# Empirical     0.276145   0.300424   0.321928   0.240086   0.259871   0.326470
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_fraction
# Normal        0.168437   0.307546   0.232641    0.192950       0.244454
# Exponential   0.215733   0.306938   0.286328    0.259124       0.260791
# Empirical     0.227986   0.329575   0.303865    0.278813       0.286516

# %%
profit_table
# Out:
#              Dataset_1  Dataset_2  Dataset_3  Dataset_4  Dataset_5  Dataset_6  \
# Normal          9028.0    12864.0    14708.0     9840.0    10980.0    11344.0
# Exponential    10812.0    11960.0    11984.0    10316.0    12464.0    11048.0
# Empirical      11428.0    13596.0    14904.0    11188.0    12900.0    12748.0
# Max            41384.0    45256.0    46296.0    46600.0    49640.0    39048.0
#
#              Dataset_7  Dataset_8  Dataset_9  Dataset_10  mean_profit  \
# Normal          8248.0    14184.0    10400.0      8036.0      10963.2
# Exponential    10564.0    14156.0    12800.0     10792.0      11689.6
# Empirical      11164.0    15200.0    13584.0     11612.0      12832.4
# Max            48968.0    46120.0    44704.0     41648.0      44966.4
#
#               std_profit
# Normal       2223.060809
# Exponential  1149.646485
# Empirical    1414.427884
# Max          3203.875254

# %%
mse_table = pd.DataFrame(mse_lst,index=col_name,columns=['Cross Validation MSE'])
mse_table
# Out:
#             Cross Validation MSE
# Dataset_1            1238.894785
# Dataset_2            1239.319239
# Dataset_3            1580.682025
# Dataset_4            2478.604027
# Dataset_5            3984.838562
# Dataset_6             986.496340
# Dataset_7            2589.709764
# Dataset_8            1119.820912
# Dataset_9            1868.959193
# Dataset_10           1312.077523

# %%
print(f"Average 10 fold CV MSE:  {float(mse_table.mean())}")
# Out:
# Average 10 fold CV MSE:  1839.9402370682026

# %%
profit_table.to_csv(".\\Model_Selection_Result\\4.1A_Decision_tree.csv")

# %%
name = "4.1A_Decision_tree.csv"
mse_table.to_csv(f".\\Model_CV_Result_MSE\\{name}")

# %%
f = pd.DataFrame(fraction_table['mean_fraction'])
f = f.transpose().reset_index()
f.to_csv(f".\\Model_CV_Result_Efficiency\\{name}")
